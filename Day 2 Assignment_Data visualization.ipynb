# %% [markdown]
# ### Data visualization
# ### Day 2 Assignment

# %% [markdown]
# #### Question 1
# #### Create a dataframe with 10 rows on random numbers and 4 columns, (columns labelled as a,b,c,d) and plot a bar chart.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
from numpy.random import randn,randint,uniform,sample

# %%
df = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -1.515557  1.070244  0.688392  0.057754
# 1  0.233248  1.049547  1.003192 -0.532578
# 2 -0.685169 -0.920803 -0.352632 -1.386570
# 3  0.158654 -3.251743 -2.388177  0.908869
# 4  0.273251 -0.899519  0.234654 -1.731700
# 5  0.995619 -1.212306 -0.381192 -0.719384
# 6  1.356885  0.428708  0.887641  1.154662
# 7 -0.058937 -2.040902 -0.026559 -0.380493
# 8 -0.904663 -0.906750  0.660380  0.818760
# 9 -1.270261 -0.907077 -2.152412  1.319761

# %%
df.plot(kind='bar',title='Bar Chart',figsize=(16,18),grid=True,legend = True)
plt.show()
