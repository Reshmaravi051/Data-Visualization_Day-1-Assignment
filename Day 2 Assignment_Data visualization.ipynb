# %% [markdown]
# #### Question 1
# #### Create a dataframe with 10 rows on random numbers and 4 columns, (columns labelled as a,b,c,d) and plot a bar chart.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
from numpy.random import randn,randint,uniform,sample

# %%
df = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.031660 -0.368122 -0.354272  1.200931
# 1 -0.088597 -1.181225  0.000429  0.867036
# 2  0.243535  1.373885  1.992770 -2.521700
# 3 -0.319539  0.468614 -0.565177 -1.093423
# 4 -0.221931  0.050388  1.216489  0.053400
# 5  0.799322 -0.432961 -0.286286 -1.481940
# 6 -1.667899 -0.076510 -0.185931  2.077144
# 7  0.477820 -1.128573  0.841868 -0.219505
# 8  2.258376 -1.219116  0.120060  0.865408
# 9  0.408525  0.221154 -1.265246 -1.004559

# %%
df.plot(kind='bar',title='Bar Chart',figsize=(16,18),grid=True,legend = True)
plt.show()
